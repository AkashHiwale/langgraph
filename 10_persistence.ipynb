# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from dotenv import load_dotenv
from langgraph.checkpoint.memory import InMemorySaver
from langchain_groq import ChatGroq
from dotenv import load_dotenv
import os
# Out:
# c:\Git-Projects\langgraph\venv\Lib\site-packages\langchain_core\_api\deprecation.py:26: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %%
load_dotenv()
# Out:
# True

# %%
llm = ChatGroq(
    model="llama-3.1-8b-instant",
    api_key=os.getenv("GROQ_API_KEY")
)

# %%
class JokeState(TypedDict):

    topic: str
    joke: str
    explanation: str

# %%
def generate_joke(state: JokeState):

    prompt = f'generate a joke on the topic {state["topic"]}'
    response = llm.invoke(prompt).content

    return {'joke': response}

# %%
def generate_explanation(state: JokeState):

    prompt = f'write an explanation for the joke - {state["joke"]}'
    response = llm.invoke(prompt).content

    return {'explanation': response}

# %%
graph = StateGraph(JokeState)

graph.add_node('generate_joke', generate_joke)
graph.add_node('generate_explanation', generate_explanation)

graph.add_edge(START, 'generate_joke')
graph.add_edge('generate_joke', 'generate_explanation')
graph.add_edge('generate_explanation', END)

checkpointer = InMemorySaver()

workflow = graph.compile(checkpointer=checkpointer)

# %%
config1 = {"configurable": {"thread_id": "1"}}
workflow.invoke({'topic':'pizza'}, config=config1)
# Out:
# {'topic': 'pizza',
#  'joke': 'Why was the pizza in a bad mood? \n\nBecause it was feeling a little crusty.',
#  'explanation': 'This joke is a play on words, using a pun to create humor. The phrase "feeling a little crusty" has a double meaning here. In everyday language, "crusty" is often used to describe someone who is irritable or in a bad mood. However, in the context of pizza, the crust is the hard outer layer of the food.\n\nThe joke relies on this wordplay, where the initial assumption is that the pizza is feeling bad because it\'s irritable, but the punchline reveals that it\'s actually "crusty" because it\'s a pizza. This unexpected twist creates a sense of surprise and amusement, making it a clever and lighthearted joke.'}

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood? \n\nBecause it was feeling a little crusty.', 'explanation': 'This joke is a play on words, using a pun to create humor. The phrase "feeling a little crusty" has a double meaning here. In everyday language, "crusty" is often used to describe someone who is irritable or in a bad mood. However, in the context of pizza, the crust is the hard outer layer of the food.\n\nThe joke relies on this wordplay, where the initial assumption is that the pizza is feeling bad because it\'s irritable, but the punchline reveals that it\'s actually "crusty" because it\'s a pizza. This unexpected twist creates a sense of surprise and amusement, making it a clever and lighthearted joke.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d8f52-c91a-6395-8002-f5deb349a304'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2025-12-14T13:59:57.481415+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d8f52-c5c1-6178-8001-5a73979142f1'}}, tasks=(), interrupts=())

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood? \n\nBecause it was feeling a little crusty.', 'explanation': 'This joke is a play on words, using a pun to create humor. The phrase "feeling a little crusty" has a double meaning here. In everyday language, "crusty" is often used to describe someone who is irritable or in a bad mood. However, in the context of pizza, the crust is the hard outer layer of the food.\n\nThe joke relies on this wordplay, where the initial assumption is that the pizza is feeling bad because it\'s irritable, but the punchline reveals that it\'s actually "crusty" because it\'s a pizza. This unexpected twist creates a sense of surprise and amusement, making it a clever and lighthearted joke.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d8f52-c91a-6395-8002-f5deb349a304'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2025-12-14T13:59:57.481415+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d8f52-c5c1-6178-8001-5a73979142f1'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood? \n\nBecause it was feeling a little crusty.'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d8f52-c5c1-6178-8001-5a73979142f1'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2025-12-14T13:59:57.130348+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d8f52-b628-619d-8000-da6808128e19'}}, tasks=(PregelTask(id='0d5dba65-eca8-917c-c9bb-779d8803171a', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This joke is a play on words, using a pun to create humor. The phrase "feeling a little crusty" has a double meaning here. In everyday language, "crusty" is often used to describe someone who is irritable or in a bad mood. However, in the context of pizza, the crust is the hard outer layer of the food.\n\nThe joke relies on this wordplay, where the initial assumption is that the pizza is feeling bad because it\'s irritable, but the punchline reveals that it\'s actually "crusty" because it\'s a pizza. This unexpected twist creates a sense of surprise and amusement, making it a clever and lighthearted joke.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d8f52-b628-619d-8000-da6808128e19'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2025-12-14T13:59:55.494806+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d8f52-b621-6449-bfff-6e345fedaedb'}}, tasks=(PregelTask(id='ccd9a147-b8c7-0fbc-9b17-65bd167d2ef2', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why was the pizza in a bad mood? \n\nBecause it was feeling a little crusty.'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d8f52-b621-6449-bfff-6e345fedaedb'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2025-12-14T13:59:55.492028+00:00', parent_config=None, tasks=(PregelTask(id='b1c53487-b753-eaeb-cc10-774ee25d870f', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=())]

# %%
config2 = {"configurable": {"thread_id": "2"}}
workflow.invoke({'topic':'pasta'}, config=config2)
# Out:
# {'topic': 'pasta',
#  'joke': 'Why did the spaghetti go to therapy? \n\nBecause it was feeling a little "twisted."',
#  'explanation': 'The joke "Why did the spaghetti go to therapy? Because it was feeling a little \'twisted\'" is a play on words. It uses a pun to create humor.\n\nIn this joke, "twisted" has a double meaning:\n\n1. In the context of the joke, "twisted" can refer to the shape of spaghetti, which is a long, curved, and twisted noodle.\n2. In psychology, "twisted" is also a colloquialism for being emotionally disturbed or having a warped mental state, which is a common reason why people go to therapy.\n\nThe joke relies on this wordplay to create a pun that connects the physical characteristics of spaghetti (twisted shape) with the emotional state of needing therapy (feeling twisted). The unexpected twist (pun intended) on the meaning of the word "twisted" creates the humor in the joke.'}

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood? \n\nBecause it was feeling a little crusty.', 'explanation': 'This joke is a play on words, using a pun to create humor. The phrase "feeling a little crusty" has a double meaning here. In everyday language, "crusty" is often used to describe someone who is irritable or in a bad mood. However, in the context of pizza, the crust is the hard outer layer of the food.\n\nThe joke relies on this wordplay, where the initial assumption is that the pizza is feeling bad because it\'s irritable, but the punchline reveals that it\'s actually "crusty" because it\'s a pizza. This unexpected twist creates a sense of surprise and amusement, making it a clever and lighthearted joke.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d8f52-c91a-6395-8002-f5deb349a304'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2025-12-14T13:59:57.481415+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d8f52-c5c1-6178-8001-5a73979142f1'}}, tasks=(), interrupts=())

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood? \n\nBecause it was feeling a little crusty.', 'explanation': 'This joke is a play on words, using a pun to create humor. The phrase "feeling a little crusty" has a double meaning here. In everyday language, "crusty" is often used to describe someone who is irritable or in a bad mood. However, in the context of pizza, the crust is the hard outer layer of the food.\n\nThe joke relies on this wordplay, where the initial assumption is that the pizza is feeling bad because it\'s irritable, but the punchline reveals that it\'s actually "crusty" because it\'s a pizza. This unexpected twist creates a sense of surprise and amusement, making it a clever and lighthearted joke.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d8f52-c91a-6395-8002-f5deb349a304'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2025-12-14T13:59:57.481415+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d8f52-c5c1-6178-8001-5a73979142f1'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood? \n\nBecause it was feeling a little crusty.'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d8f52-c5c1-6178-8001-5a73979142f1'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2025-12-14T13:59:57.130348+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d8f52-b628-619d-8000-da6808128e19'}}, tasks=(PregelTask(id='0d5dba65-eca8-917c-c9bb-779d8803171a', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This joke is a play on words, using a pun to create humor. The phrase "feeling a little crusty" has a double meaning here. In everyday language, "crusty" is often used to describe someone who is irritable or in a bad mood. However, in the context of pizza, the crust is the hard outer layer of the food.\n\nThe joke relies on this wordplay, where the initial assumption is that the pizza is feeling bad because it\'s irritable, but the punchline reveals that it\'s actually "crusty" because it\'s a pizza. This unexpected twist creates a sense of surprise and amusement, making it a clever and lighthearted joke.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d8f52-b628-619d-8000-da6808128e19'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2025-12-14T13:59:55.494806+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d8f52-b621-6449-bfff-6e345fedaedb'}}, tasks=(PregelTask(id='ccd9a147-b8c7-0fbc-9b17-65bd167d2ef2', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why was the pizza in a bad mood? \n\nBecause it was feeling a little crusty.'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d8f52-b621-6449-bfff-6e345fedaedb'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2025-12-14T13:59:55.492028+00:00', parent_config=None, tasks=(PregelTask(id='b1c53487-b753-eaeb-cc10-774ee25d870f', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=())]

# %% [markdown]
# Time Travel

# %%
workflow.get_state({"configurable": {"thread_id": "1", "checkpoint_id": "1f0d8f52-c5c1-6178-8001-5a73979142f1"}})
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood? \n\nBecause it was feeling a little crusty.'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_id': '1f0d8f52-c5c1-6178-8001-5a73979142f1'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2025-12-14T13:59:57.130348+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d8f52-b628-619d-8000-da6808128e19'}}, tasks=(PregelTask(id='0d5dba65-eca8-917c-c9bb-779d8803171a', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This joke is a play on words, using a pun to create humor. The phrase "feeling a little crusty" has a double meaning here. In everyday language, "crusty" is often used to describe someone who is irritable or in a bad mood. However, in the context of pizza, the crust is the hard outer layer of the food.\n\nThe joke relies on this wordplay, where the initial assumption is that the pizza is feeling bad because it\'s irritable, but the punchline reveals that it\'s actually "crusty" because it\'s a pizza. This unexpected twist creates a sense of surprise and amusement, making it a clever and lighthearted joke.'}),), interrupts=())

# %%
workflow.invoke(None, {"configurable": {"thread_id": "1", "checkpoint_id": "1f0d8f52-c5c1-6178-8001-5a73979142f1"}})
# Out:
# {'topic': 'pizza',
#  'joke': 'Why was the pizza in a bad mood? \n\nBecause it was feeling a little crusty.',
#  'explanation': 'This joke is a play on words and relies on a common idiomatic expression. \n\nA "crusty" person is typically someone who is feeling irritable, grumpy, or short-tempered. However, in this joke, the phrase "feeling a little crusty" has a double meaning. \n\nA pizza has a crust, which is the outer layer of the food. The punchline of the joke is using the term "crusty" to describe the pizza\'s mood, but also referencing the physical crust of the pizza, creating a clever and humorous connection between the two meanings.\n\nThis type of wordplay is known as a pun, and it\'s a common technique used in jokes to create humor by exploiting multiple meanings of words or phrases. In this case, the joke is using the word "crusty" to create a clever connection between the pizza\'s mood and its physical characteristics, resulting in a humorous and lighthearted pun.'}

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood? \n\nBecause it was feeling a little crusty.', 'explanation': 'This joke is a play on words and relies on a common idiomatic expression. \n\nA "crusty" person is typically someone who is feeling irritable, grumpy, or short-tempered. However, in this joke, the phrase "feeling a little crusty" has a double meaning. \n\nA pizza has a crust, which is the outer layer of the food. The punchline of the joke is using the term "crusty" to describe the pizza\'s mood, but also referencing the physical crust of the pizza, creating a clever and humorous connection between the two meanings.\n\nThis type of wordplay is known as a pun, and it\'s a common technique used in jokes to create humor by exploiting multiple meanings of words or phrases. In this case, the joke is using the word "crusty" to create a clever connection between the pizza\'s mood and its physical characteristics, resulting in a humorous and lighthearted pun.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d8f57-9199-690a-8002-dd765a89a287'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2025-12-14T14:02:05.879265+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d8f52-c5c1-6178-8001-5a73979142f1'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood? \n\nBecause it was feeling a little crusty.', 'explanation': 'This joke is a play on words, using a pun to create humor. The phrase "feeling a little crusty" has a double meaning here. In everyday language, "crusty" is often used to describe someone who is irritable or in a bad mood. However, in the context of pizza, the crust is the hard outer layer of the food.\n\nThe joke relies on this wordplay, where the initial assumption is that the pizza is feeling bad because it\'s irritable, but the punchline reveals that it\'s actually "crusty" because it\'s a pizza. This unexpected twist creates a sense of surprise and amusement, making it a clever and lighthearted joke.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d8f52-c91a-6395-8002-f5deb349a304'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2025-12-14T13:59:57.481415+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d8f52-c5c1-6178-8001-5a73979142f1'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood? \n\nBecause it was feeling a little crusty.'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d8f52-c5c1-6178-8001-5a73979142f1'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2025-12-14T13:59:57.130348+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d8f52-b628-619d-8000-da6808128e19'}}, tasks=(PregelTask(id='0d5dba65-eca8-917c-c9bb-779d8803171a', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This joke is a play on words, using a pun to create humor. The phrase "feeling a little crusty" has a double meaning here. In everyday language, "crusty" is often used to describe someone who is irritable or in a bad mood. However, in the context of pizza, the crust is the hard outer layer of the food.\n\nThe joke relies on this wordplay, where the initial assumption is that the pizza is feeling bad because it\'s irritable, but the punchline reveals that it\'s actually "crusty" because it\'s a pizza. This unexpected twist creates a sense of surprise and amusement, making it a clever and lighthearted joke.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d8f52-b628-619d-8000-da6808128e19'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2025-12-14T13:59:55.494806+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d8f52-b621-6449-bfff-6e345fedaedb'}}, tasks=(PregelTask(id='ccd9a147-b8c7-0fbc-9b17-65bd167d2ef2', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why was the pizza in a bad mood? \n\nBecause it was feeling a little crusty.'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d8f52-b621-6449-bfff-6e345fedaedb'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2025-12-14T13:59:55.492028+00:00', parent_config=None, tasks=(PregelTask(id='b1c53487-b753-eaeb-cc10-774ee25d870f', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=())]
