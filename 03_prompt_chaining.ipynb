# %%
from langgraph.graph import StateGraph, START, END
from langchain_groq import ChatGroq
from typing import TypedDict
from dotenv import load_dotenv
import os
# Out:
# c:\Git-Projects\langgraph\venv\Lib\site-packages\langchain_core\_api\deprecation.py:26: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatGroq(
    model="llama-3.1-8b-instant",
    api_key=os.getenv("GROQ_API_KEY")
)

# %%
class BlogState(TypedDict):

    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:

    # fetch title
    title = state['title']

    # call llm gen outline
    prompt = f'Generate a detailed outline for a blog on the topic - {title}'
    outline = model.invoke(prompt).content

    # update state
    state['outline'] = outline

    return state

# %%
def create_blog(state: BlogState) -> BlogState:

    title = state['title']
    outline = state['outline']

    prompt = f'Write a detailed blog on the title - {title} using the follwing outline \n {outline}'

    content = model.invoke(prompt).content

    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)

# nodes
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

# edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

# %%
intial_state = {'title': 'Rise of AI in India'}

final_state = workflow.invoke(intial_state)

print(final_state)
# Out:
# {'title': 'Rise of AI in India', 'outline': '**Blog Title:** "The Rise of AI in India: Opportunities, Challenges, and Future Prospects"\n\n**I. Introduction**\n\n* Brief overview of Artificial Intelligence (AI) and its growing importance globally\n* Significance of AI in India, particularly in the context of its growing economy and digital transformation\n* Thesis statement: India is poised to become a major hub for AI innovation and adoption, driven by government initiatives, technological advancements, and growing demand from industries.\n\n**II. AI in India: Current Landscape and Trends**\n\n* Overview of the current AI landscape in India, including key players, startups, and research institutions\n* Discussion of AI applications in various sectors, such as:\n\t+ Healthcare: AI-powered diagnosis, personalized medicine, and telemedicine\n\t+ Education: AI-driven learning platforms, adaptive assessments, and virtual teaching assistants\n\t+ Finance: AI-powered risk management, credit scoring, and chatbots\n\t+ Manufacturing: AI-optimized production planning, predictive maintenance, and quality control\n* Analysis of the current talent pool and workforce development initiatives in AI-related skills\n\n**III. Government Initiatives and Policies Supporting AI in India**\n\n* Overview of government initiatives, such as:\n\t+ Digital India: Aims to transform India into a digitally empowered society\n\t+ Make in India: Focuses on promoting domestic manufacturing and innovation\n\t+ Skill India: Emphasizes the importance of developing skills for the digital economy\n\t+ AI for All: Aims to develop AI solutions for social good and inclusivity\n* Discussion of policies and regulations, such as data protection, cybersecurity, and ethics guidelines\n\n**IV. Challenges and Opportunities in AI Adoption in India**\n\n* Discussion of challenges, including:\n\t+ Data availability and quality\n\t+ Cybersecurity risks\n\t+ Ethics and bias in AI decision-making\n\t+ Talent acquisition and retention\n\t+ Infrastructure and resource constraints\n* Opportunities, including:\n\t+ Potential for job creation and economic growth\n\t+ Improving healthcare outcomes and quality of life\n\t+ Enhancing education and skills development\n\t+ Fostering innovation and entrepreneurship\n\n**V. Case Studies: AI Success Stories in India**\n\n* In-depth analysis of successful AI projects and initiatives in India, such as:\n\t+ AI-powered healthcare platforms, like Practo and Apollo Hospitals\n\t+ AI-driven education platforms, like Byju\'s and Unacademy\n\t+ AI-powered finance platforms, like Paytm and ICICI Bank\n\t+ AI-optimized manufacturing processes, like Tata Motors and Mahindra & Mahindra\n\n**VI. Future Prospects and Predictions**\n\n* Discussion of future trends and predictions, including:\n\t+ Growth of AI adoption in sectors like agriculture, logistics, and transportation\n\t+ Increased focus on AI ethics, governance, and accountability\n\t+ Development of more advanced AI technologies, like explainable AI and transfer learning\n\t+ Expansion of AI research and innovation in India, driven by government initiatives and private sector investments\n\n**VII. Conclusion**\n\n* Recap of the rise of AI in India and its potential for growth and transformation\n* Final thoughts on the importance of AI adoption, innovation, and responsible AI development in India.\n\nThis detailed outline provides a comprehensive framework for exploring the rise of AI in India, covering its current landscape, government initiatives, challenges, opportunities, case studies, and future prospects.', 'content': "**The Rise of AI in India: Opportunities, Challenges, and Future Prospects**\n\nAs the world becomes increasingly dependent on technology, Artificial Intelligence (AI) has emerged as a key driver of innovation and growth. India, with its large and young population, is poised to become a major hub for AI innovation and adoption, driven by government initiatives, technological  ...

# %%
print(final_state['outline'])
# Out:
# **Blog Title:** "The Rise of AI in India: Opportunities, Challenges, and Future Prospects"
#
# **I. Introduction**
#
# * Brief overview of Artificial Intelligence (AI) and its growing importance globally
# * Significance of AI in India, particularly in the context of its growing economy and digital transformation
# * Thesis statement: India is poised to become a major hub for AI innovation and adoption, driven by government initiatives, technological advancements, and growing demand from industries.
#
# **II. AI in India: Current Landscape and Trends**
#
# * Overview of the current AI landscape in India, including key players, startups, and research institutions
# * Discussion of AI applications in various sectors, such as:
# 	+ Healthcare: AI-powered diagnosis, personalized medicine, and telemedicine
# 	+ Education: AI-driven learning platforms, adaptive assessments, and virtual teaching assistants
# 	+ Finance: AI-powered risk management, credit scoring, and chatbots
# 	+ Manufacturing: AI-optimized production planning, predictive maintenance, and quality control
# * Analysis of the current talent pool and workforce development initiatives in AI-related skills
#
# **III. Government Initiatives and Policies Supporting AI in India**
#
# * Overview of government initiatives, such as:
# 	+ Digital India: Aims to transform India into a digitally empowered society
# 	+ Make in India: Focuses on promoting domestic manufacturing and innovation
# 	+ Skill India: Emphasizes the importance of developing skills for the digital economy
# 	+ AI for All: Aims to develop AI solutions for social good and inclusivity
# * Discussion of policies and regulations, such as data protection, cybersecurity, and ethics guidelines
#
# **IV. Challenges and Opportunities in AI Adoption in India**
#
# * Discussion of challenges, including:
# 	+ Data availability and quality
# 	+ Cybersecurity risks
# 	+ Ethics and bias in AI decision-making
# 	+ Talent acquisition and retention
# 	+ Infrastructure and resource constraints
# * Opportunities, including:
# 	+ Potential for job creation and economic growth
# 	+ Improving healthcare outcomes and quality of life
# 	+ Enhancing education and skills development
# 	+ Fostering innovation and entrepreneurship
#
# **V. Case Studies: AI Success Stories in India**
#
# * In-depth analysis of successful AI projects and initiatives in India, such as:
# 	+ AI-powered healthcare platforms, like Practo and Apollo Hospitals
# 	+ AI-driven education platforms, like Byju's and Unacademy
# 	+ AI-powered finance platforms, like Paytm and ICICI Bank
# 	+ AI-optimized manufacturing processes, like Tata Motors and Mahindra & Mahindra
#
# **VI. Future Prospects and Predictions**
#
# * Discussion of future trends and predictions, including:
# 	+ Growth of AI adoption in sectors like agriculture, logistics, and transportation
# 	+ Increased focus on AI ethics, governance, and accountability
# 	+ Development of more advanced AI technologies, like explainable AI and transfer learning
# 	+ Expansion of AI research and innovation in India, driven by government initiatives and private sector investments
#
# **VII. Conclusion**
#
# * Recap of the rise of AI in India and its potential for growth and transformation
# * Final thoughts on the importance of AI adoption, innovation, and responsible AI development in India.
#
# This detailed outline provides a comprehensive framework for exploring the rise of AI in India, covering its current landscape, government initiatives, challenges, opportunities, case studies, and future prospects.

# %%
print(final_state['content'])
# Out:
# **The Rise of AI in India: Opportunities, Challenges, and Future Prospects**
#
# As the world becomes increasingly dependent on technology, Artificial Intelligence (AI) has emerged as a key driver of innovation and growth. India, with its large and young population, is poised to become a major hub for AI innovation and adoption, driven by government initiatives, technological advancements, and growing demand from industries.
#
# **I. Introduction**
#
# Artificial Intelligence (AI) has been making waves globally, transforming industries and revolutionizing the way we live and work. From virtual assistants to self-driving cars, AI has become an integral part of our daily lives. In India, AI is being seen as a key driver of growth and transformation, particularly in the context of the country's growing economy and digital transformation.
#
# India's government has been actively promoting AI innovation and adoption, with initiatives like Digital India, Make in India, and Skill India. These initiatives aim to develop AI solutions for social good and inclusivity, while also promoting domestic manufacturing and innovation. Furthermore, India has a large and growing talent pool, with many young professionals and students showing interest in AI-related fields.
#
# **II. AI in India: Current Landscape and Trends**
#
# The current AI landscape in India is diverse and rapidly evolving. Key players, startups, and research institutions are working together to develop AI solutions for various sectors, including healthcare, education, finance, and manufacturing.
#
# **Healthcare**
#
# AI-powered diagnosis, personalized medicine, and telemedicine are some of the key applications of AI in healthcare in India. For instance, Practo, a popular healthcare platform, has developed an AI-powered chatbot that helps patients book appointments and access medical advice. Apollo Hospitals has also launched an AI-powered platform that enables patients to book appointments and access medical records online.
#
# **Education**
#
# AI-driven learning platforms, adaptive assessments, and virtual teaching assistants are transforming the education sector in India. Byju's, a popular ed-tech platform, has developed an AI-powered learning platform that provides personalized learning experiences to students. Unacademy, another ed-tech platform, has launched an AI-powered virtual teaching assistant that helps students prepare for competitive exams.
#
# **Finance**
#
# AI-powered risk management, credit scoring, and chatbots are some of the key applications of AI in finance in India. For instance, Paytm, a popular digital payments platform, has developed an AI-powered chatbot that helps customers with queries and transactions. ICICI Bank has also launched an AI-powered platform that enables customers to access their bank accounts and perform transactions online.
#
# **Manufacturing**
#
# AI-optimized production planning, predictive maintenance, and quality control are some of the key applications of AI in manufacturing in India. For instance, Tata Motors has developed an AI-powered platform that enables predictive maintenance and quality control in its manufacturing processes. Mahindra & Mahindra has also launched an AI-powered platform that enables optimized production planning and reduced waste in its manufacturing processes.
#
# **Analysis of Talent Pool and Workforce Development Initiatives**
#
# India has a large and growing talent pool, with many young professionals and students showing interest in AI-related fields. However, there is a shortage of skilled professionals in areas like data science, machine learning, and natural language processing. To address this shortage, the government has launched initiatives like Skill India, which aims to develop skills for the digital economy.
#
# **III. Government Initiatives and Policies Supporting AI in India**
#
# The Indian government has launched several initiatives to promote AI innovation and adoption, including:
#
# * **Digital India**: Aims to transform India into a digitally empowered society, with AI being a key driver of this transformation.
# * **Make in India**: Focuses on promoting domestic manufacturing and innovation, with AI being a key enabler of this initiative.
# * **Skill India**: Emphasizes the importance of developing skills for the digital economy, with AI being a key area of focus.
# * **AI for All**: Aims to develop AI solutions for social good and inclusivity, with a focus on areas like healthcare, education, and finance.
#
# **IV. Challenges and Opportunities in AI Adoption in India**
#
# While AI adoption in India offers many opportunities, there are also several challenges that need to be addressed. Some of the key challenges include:
#
# * **Data Availability and Quality**: AI requires large amounts of high-quality data to train and validate models, which is a challenge in India due to data availability and quality issues.
# * **Cybersecurity Risks**: AI systems are vulnerable to cyber attacks, which can compromise sensitive data and disrupt operations.
# * **Ethics and Bias in AI Decision-Making**: AI systems can perpetuate biases and prejudices if they are trained on biased data, which can lead to unfair outcomes.
# * **Talent Acquisition and Retention**: India faces a shortage of skilled professionals in AI-related fields, which can hinder adoption and innovation.
# * **Infrastructure and Resource Constraints**: India's infrastructure and resources are not always up to date, which can hinder the adoption and implementation of AI systems.
#
# **Opportunities**
#
# Despite the challenges, AI adoption in India offers many opportunities, including:
#
# * **Potential for Job Creation and Economic Growth**: AI can create new job opportunities and stimulate economic growth by increasing productivity and efficiency.
# * **Improving Healthcare Outcomes and Quality of Life**: AI can improve healthcare outcomes and quality of life by enabling personalized medicine, telemedicine, and predictive analytics.
# * **Enhancing Education and Skills Development**: AI can enhance education and skills development by providing personalized learning experiences and adaptive assessments.
# * **Fostering Innovation and Entrepreneurship**: AI can foster innovation and entrepreneurship by enabling the development of new products and services.
#
# **V. Case Studies: AI Success Stories in India**
#
# Several Indian companies have successfully implemented AI solutions in various sectors, including:
#
# * **Practo**: Developed an AI-powered chatbot that helps patients book appointments and access medical advice.
# * **Apollo Hospitals**: Launched an AI-powered platform that enables patients to book appointments and access medical records online.
# * **Byju's**: Developed an AI-powered learning platform that provides personalized learning experiences to students.
# * **Unacademy**: Launched an AI-powered virtual teaching assistant that helps students prepare for competitive exams.
# * **Paytm**: Developed an AI-powered chatbot that helps customers with queries and transactions.
# * **ICICI Bank**: Launched an AI-powered platform that enables customers to access their bank accounts and perform transactions online.
# * **Tata Motors**: Developed an AI-powered platform that enables predictive maintenance and quality control in its manufacturing processes.
# * **Mahindra & Mahindra**: Launched an AI-powered platform that enables optimized production planning and reduced waste in its manufacturing processes.
#
# **VI. Future Prospects and Predictions**
#
# The future of AI in India looks promising, with several trends and predictions emerging, including:
#
# * **Growth of AI Adoption in Sectors like Agriculture, Logistics, and Transportation**: AI is expected to transform these sectors by enabling predictive analytics, optimized planning, and improved efficiency.
# * **Increased Focus on AI Ethics, Governance, and Accountability**: As AI becomes more pervasive, there will be a growing need for AI ethics, governance, and accountability frameworks to ensure that AI systems are fair, transparent, and accountable.
# * **Development of More Advanced AI Technologies**: India is expected to see the development of more advanced AI technologies, including explainable AI, transfer learning, and reinforcement learning.
# * **Expansion of AI Research and Innovation in India**: India is expected to see a surge in AI research and innovation, driven by government initiatives and private sector investments.
#
# **VII. Conclusion**
#
# In conclusion, AI is poised to transform India's economy and society, with many opportunities and challenges emerging. While there are challenges to be addressed, the Indian government's initiatives and policies are expected to support AI innovation and adoption. As AI continues to evolve, India is expected to see a surge in AI research and innovation, driven by government initiatives and private sector investments.
